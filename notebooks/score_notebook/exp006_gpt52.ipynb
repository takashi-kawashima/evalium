# %%
# %load_ext autoreload
# %autoreload 2

# %%
from notebooks.utils.display import show_scores, show_stats, show_variance

DATA_DIR = "data/exp006_gpt52/all"
LABEL = "exp006_gpt52_all"
show_stats(DATA_DIR, label=LABEL)
show_variance(DATA_DIR, label=LABEL)
show_scores(
    DATA_DIR,
    label=LABEL,
    columns=["best_id", "best_top1_new_id", "best_top1_score", "best_avg_similarity"],
)
# show_follow_up_scores(DATA_DIR, label=LABEL)
# Out:
# ## exp006_gpt52_all — Token & Latency Stats
# `data/exp006_gpt52/all` — 21 conversations
# <style type="text/css">
# ...

# %%
from notebooks.utils.display import (
    compare_follow_up_scores,
    compare_scores,
    compare_stats,
)

BASELINE_DIR = "data/baseline"
TARGET_DIR = "data/exp006_gpt52/all"
BASELINE_LABEL = "Baseline"
TARGET_LABEL = "exp006_gpt52_all"

compare_scores(
    BASELINE_DIR,
    TARGET_DIR,
    BASELINE_LABEL,
    TARGET_LABEL,
    columns=["best_avg_similarity"],
    lower=-0.04,
)
compare_follow_up_scores(BASELINE_DIR, TARGET_DIR, BASELINE_LABEL, TARGET_LABEL)
compare_stats(BASELINE_DIR, TARGET_DIR, BASELINE_LABEL, TARGET_LABEL)
# Out:
# ## exp006_gpt52_all vs Baseline — Agent Response Diff
# Target: `data/exp006_gpt52/all` / Baseline: `data/baseline`
# Green (>= +0) / Yellow (-0.04 〜 +0) / Red (< -0.04) / Gray (N/A)
# <style type="text/css">
# #T_27ac5_row0_col2, #T_27ac5_row1_col2, #T_27ac5_row2_col2, #T_27ac5_row3_col2, #T_27ac5_row4_col2, #T_27ac5_row6_col2, #T_27ac5_row7_col2, #T_27ac5_row8_col2, #T_27ac5_row9_col2, #T_27ac5_row10_col2, #T_27ac5_row11_col2, #T_27ac5_row12_col2, #T_27ac5_row13_col2, #T_27ac5_row15_col2, #T_27ac5_row16_col2, #T_27ac5_row17_col2, #T_27ac5_row18_col2, #T_27ac5_row19_col2, #T_27ac5_row20_col2, #T_27ac5_row21_col2, #T_27ac5_row22_col2, #T_27ac5_row23_col2, #T_27ac5_row24_col2 {
#   background-color: #ffc7ce;
#   color: #9c0006;
#   text-align: center;
# }
# #T_27ac5_row5_col2, #T_27ac5_row14_col2 {
#   background-color: #ffeb9c;
#   color: #9c5700;
#   text-align: center;
# }
# </style>
# <table id="T_27ac5">
#   <caption>exp006_gpt52_all − Baseline: Agent Response</caption>
# ...

# %%
from notebooks.utils.display import show_scores, show_stats, show_variance

DATA_DIR = "data/exp006_gpt52/all_scenario"
LABEL = "exp006_gpt52 (Scenario)"
show_stats(DATA_DIR, label=LABEL)
show_variance(DATA_DIR, label=LABEL)
show_scores(
    DATA_DIR,
    label=LABEL,
    columns=["best_id", "best_top1_new_id", "best_top1_score", "best_avg_similarity"],
)
# Out:
# ## exp006_gpt52 (Scenario) — Token & Latency Stats
# `data/exp006_gpt52/all_scenario` — 6 conversations
# <style type="text/css">
# #T_413f6_row0_col1, #T_413f6_row0_col2, #T_413f6_row0_col3, #T_413f6_row0_col4, #T_413f6_row0_col5, #T_413f6_row0_col6, #T_413f6_row1_col1, #T_413f6_row1_col2, #T_413f6_row1_col3, #T_413f6_row1_col4, #T_413f6_row1_col5, #T_413f6_row1_col6, #T_413f6_row2_col1, #T_413f6_row2_col2, #T_413f6_row2_col3, #T_413f6_row2_col4, #T_413f6_row2_col5, #T_413f6_row2_col6, #T_413f6_row3_col1, #T_413f6_row3_col2, #T_413f6_row3_col3, #T_413f6_row3_col4, #T_413f6_row3_col5, #T_413f6_row3_col6, #T_413f6_row4_col1, #T_413f6_row4_col2, #T_413f6_row4_col3, #T_413f6_row4_col4, #T_413f6_row4_col5, #T_413f6_row4_col6, #T_413f6_row5_col1, #T_413f6_row5_col2, #T_413f6_row5_col3, #T_413f6_row5_col4, #T_413f6_row5_col5, #T_413f6_row5_col6, #T_413f6_row6_col1, #T_413f6_row6_col2, #T_413f6_row6_col3, #T_413f6_row6_col4, #T_413f6_row6_col5, #T_413f6_row6_col6 {
#   text-align: center;
# ...

# %%
from notebooks.utils.display import (
    compare_follow_up_scores,
    compare_scores,
    compare_stats,
)

BASELINE_DIR = "data/baseline_scenario"
TARGET_DIR = "data/exp006_gpt52/all_scenario"
BASELINE_LABEL = "Baseline (Scenario)"
TARGET_LABEL = "exp006_gpt52 (Scenario)"

compare_scores(
    BASELINE_DIR,
    TARGET_DIR,
    BASELINE_LABEL,
    TARGET_LABEL,
    columns=["best_avg_similarity"],
    lower=-0.04,
)
compare_follow_up_scores(BASELINE_DIR, TARGET_DIR, BASELINE_LABEL, TARGET_LABEL)
# Out:
# ## exp006_gpt52 (Scenario) vs Baseline (Scenario) — Agent Response Diff
# Target: `data/exp006_gpt52/all_scenario` / Baseline: `data/baseline_scenario`
# Green (>= +0) / Yellow (-0.04 〜 +0) / Red (< -0.04) / Gray (N/A)
# <style type="text/css">
# #T_46187_row0_col2, #T_46187_row1_col2, #T_46187_row2_col2, #T_46187_row3_col2, #T_46187_row4_col2, #T_46187_row5_col2, #T_46187_row6_col2 {
#   background-color: #ffc7ce;
#   color: #9c0006;
#   text-align: center;
# }
# </style>
# <table id="T_46187">
#   <caption>exp006_gpt52 (Scenario) − Baseline (Scenario): Agent Response</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46187_level0_col0" class="col_heading level0 col0" >conversation_name</th>
#       <th id="T_46187_level0_col1" class="col_heading level0 col1" >best_id</th>
#       <th id="T_46187_level0_col2" class="col_heading level0 col2" >best_avg_similarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...
