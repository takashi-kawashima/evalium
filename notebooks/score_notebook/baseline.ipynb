# %%
# %load_ext autoreload
# %autoreload 2

# %%
from notebooks.utils.display import (
    show_follow_up_scores,
    show_scores,
    show_stats,
    show_variance,
)

DATA_DIR = "data/baseline"
LABEL = "Baseline"

show_stats(DATA_DIR, label=LABEL)
show_variance(DATA_DIR, label=LABEL)
show_scores(DATA_DIR, label=LABEL, columns=["best_top1_score", "best_avg_similarity"])
show_follow_up_scores(DATA_DIR, label=LABEL)
# Out:
# ## Baseline — Token & Latency Stats
# `data/baseline` — 21 conversations
# <style type="text/css">
# ...

# %%
from notebooks.utils.display import (
    show_follow_up_scores,
    show_scores,
    show_stats,
    show_variance,
)

DATA_DIR = "data/baseline_scenario"
LABEL = "Baseline (Scenario)"

show_stats(DATA_DIR, label=LABEL)
show_variance(DATA_DIR, label=LABEL)
show_scores(DATA_DIR, label=LABEL, columns=["best_top1_score", "best_avg_similarity"])
show_follow_up_scores(DATA_DIR, label=LABEL)
# Out:
# ## Baseline (Scenario) — Token & Latency Stats
# `data/baseline_scenario` — 6 conversations
# <style type="text/css">
# #T_f1a7b_row0_col1, #T_f1a7b_row0_col2, #T_f1a7b_row0_col3, #T_f1a7b_row0_col4, #T_f1a7b_row1_col1, #T_f1a7b_row1_col2, #T_f1a7b_row1_col3, #T_f1a7b_row1_col4, #T_f1a7b_row2_col1, #T_f1a7b_row2_col2, #T_f1a7b_row2_col3, #T_f1a7b_row2_col4, #T_f1a7b_row3_col1, #T_f1a7b_row3_col2, #T_f1a7b_row3_col3, #T_f1a7b_row3_col4, #T_f1a7b_row4_col1, #T_f1a7b_row4_col2, #T_f1a7b_row4_col3, #T_f1a7b_row4_col4, #T_f1a7b_row5_col1, #T_f1a7b_row5_col2, #T_f1a7b_row5_col3, #T_f1a7b_row5_col4, #T_f1a7b_row6_col1, #T_f1a7b_row6_col2, #T_f1a7b_row6_col3, #T_f1a7b_row6_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_f1a7b">
#   <caption>Baseline (Scenario) Avg Token & Latency</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1a7b_level0_col0" class="col_heading level0 col0" >conversation_name</th>
# ...
